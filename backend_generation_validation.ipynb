# %% [markdown]
# # Backend Generation Validation
#
# This notebook runs the backend, sends a hospital management prompt to the generation endpoint, downloads the generated ZIP, and inspects the contents for `docs/` and `security/ir.model.access.csv`.

# %% [markdown]
# ## 1. Run the backend service

# %% [markdown]
# ## 2. Send Odoo module generation request

# %% [markdown]
# ## 3. Download the generated ZIP

# %% [markdown]
# ## 4. Inspect ZIP contents

# %% [markdown]
# ## 5. Validate security/ir.model.access.csv
